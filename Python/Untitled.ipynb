# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id="5a7e8a89e9944dea853637f03abd08ac",
                                                           client_secret="c2ee9477e8714f6e979dc5ab186d21f6"))

# %%
sp

# %%
results = sp.search(q='Ed Sheeran', limit=20)
for idx, track in enumerate(results['tracks']['items']):
    print(idx, track['name'])
# Out:
# 0 Bad Habits
# 1 I Can't Get Enough of You
# 2 Visiting Hours
# 3 Perfect
# 4 Happier
# 5 Perfect
# 6 Galway Girl
# 7 Thinking out Loud
# 8 Shape of You
# 9 Perfect
# 10 Bad Habits
# 11 River (feat. Ed Sheeran)
# 12 Perfect
# 13 Shape of You
# 14 Those Kinda Nights (feat. Ed Sheeran)
# 15 Perfect
# 16 Perfect Duet (Ed Sheeran & Beyoncé)
# 17 Photograph
# 18 Bad Habits
# 19 Own It (feat. Ed Sheeran & Burna Boy)

# %%
results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Ed+Sheeran&type=track&offset=0&limit=30',
#   'items': [{'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#        'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#        'id': '6eUKZXaKkcviH0Ku9w2n3V',
#        'name': 'Ed Sheeran',
#        'type': 'artist',
#        'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
# ...
